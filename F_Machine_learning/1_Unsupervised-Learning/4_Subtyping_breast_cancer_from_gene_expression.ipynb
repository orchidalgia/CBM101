# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026458
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026459
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026460
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026461
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026462
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026463
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026464
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026465
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026466
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026467
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026468
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026469
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026470
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026471
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026472
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026473
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026474
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026475
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026476
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026477
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026478
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026479
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026480
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026481
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026482
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026483
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026484
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026485
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026486
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026487
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026488
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026489
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026490
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026491
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026492
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026493
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026494
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026495
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026496
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026497
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026498
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026499
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026500
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026501
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026502
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026503
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026504
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026505
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026506
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026507
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026508
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026509
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026510
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026511
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026512
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026513
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026514
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026515
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026516
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026517
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026518
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026519
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026520
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026521
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026522
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026523
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026524
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026525
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026526
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026527
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026528
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026529
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026530
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026531
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026532
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026533
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026534
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026535
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026536
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026537
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026538
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026539
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026540
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026541
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026542
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026543
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026544
# 16-Jun-2022 11:15:47 DEBUG GEOparse - SAMPLE: GSM3026545
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026546
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026547
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026548
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026549
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026550
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026551
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026552
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026553
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026554
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026555
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026556
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026557
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026558
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026559
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026560
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026561
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026562
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026563
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026564
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026565
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026566
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026567
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026568
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026569
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026570
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026571
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026572
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026573
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026574
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026575
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026576
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026577
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026578
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026579
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026580
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026581
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026582
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026583
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026584
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026585
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026586
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026587
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026588
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026589
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026590
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026591
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026592
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026593
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026594
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026595
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026596
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026597
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026598
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026599
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026600
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026601
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026602
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026603
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026604
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026605
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026606
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026607
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026608
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026609
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026610
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026611
# 16-Jun-2022 11:15:48 DEBUG GEOparse - SAMPLE: GSM3026612

# %%
dir(rna_seq)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__metaclass__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_metadata_as_string',
#  '_get_object_as_soft',
#  '_phenotype_data',
#  'database',
#  'download_SRA',
#  'download_supplementary_files',
#  'geotype',
#  'get_accession',
#  'get_metadata_attribute',
#  'get_type',
#  'gpls',
#  'gsms',
#  'merge_and_average',
#  'metadata',
#  'name',
#  'phenotype_data',
#  'pivot_and_annotate',
#  'pivot_samples',
#  'relations',
#  'show_metadata',
#  'to_soft']

# %%
rna_seq.download_SRA??

# %%
rna_seq.geotype
# Out:
# 'SERIES'

# %%
rna_seq.phenotype_data.shape
# Out:
# (768, 37)

# %%
rna_seq.phenotype_data.shape
# Out:
# (768, 37)

# %%
rna_seq.to_soft('test', False)

# %%
cafs = pd.read_csv('data/CAFs.txt', sep='\t')

# %%
sorted(cafs.cluster.unique())
# Out:
# [1, 2, 3, 4]

# %%
expr = cafs

# %% [markdown]
# ### The expression matrix
# 716 cells has been sequenced, and the expression levels has been assessed for 558 genes. Arranging the cells as rows and genes as columns we obtain an *expression matrix*.

# %%
expr.shape
# Out:
# (716, 558)

# %%
expr
# Out:
#                  1110020A21Rik  1110046J04Rik  1190002F15Rik  1500015A07Rik  \
# SS2_15_0048_A3        0.000000            0.0       0.000000            0.0
# SS2_15_0048_A6        0.000000            0.0       0.000000            0.0
# SS2_15_0048_A5        0.000000            0.0       0.000000            0.0
# SS2_15_0048_A4        0.000000            0.0       0.000000            0.0
# SS2_15_0048_A1       43.324338            0.0       0.000000            0.0
# ...                        ...            ...            ...            ...
# SS2_15_0049_P19       0.000000            0.0       0.000000            0.0
# SS2_15_0049_P18      37.696628            0.0       0.000000            0.0
# SS2_15_0049_P21       0.000000            0.0      53.257827            0.0
# SS2_15_0049_P23       0.000000            0.0       0.000000            0.0
# SS2_15_0049_P22       0.000000            0.0       0.000000            0.0
#
#                  1500015O10Rik  1700010K23Rik  1700012D01Rik  1810011H11Rik  \
# SS2_15_0048_A3        0.000000            0.0            0.0       0.000000
# SS2_15_0048_A6        0.000000            0.0            0.0     230.755035
# SS2_15_0048_A5        0.000000            0.0            0.0     375.177236
# SS2_15_0048_A4      891.488043            0.0            0.0       0.000000
# SS2_15_0048_A1        0.000000            0.0            0.0      20.527119
# ...                        ...            ...            ...            ...
# SS2_15_0049_P19    1012.999120            0.0            0.0       0.000000
# SS2_15_0049_P18    1562.238996            0.0            0.0       0.000000
# SS2_15_0049_P21       5.817578            0.0            0.0     112.228306
# SS2_15_0049_P23    2411.205731            0.0            0.0       0.000000
# SS2_15_0049_P22     122.011558            0.0            0.0     593.342291
#
#                  2010204K13Rik  2310057J18Rik  ...  Wif1  Wisp2         Yy2  \
# SS2_15_0048_A3        0.000000       0.000000  ...   0.0    0.0  107.526495
# SS2_15_0048_A6        0.000000       0.000000  ...   0.0    0.0    0.000000
# SS2_15_0048_A5        0.000000       0.000000  ...   0.0    0.0    0.000000
# SS2_15_0048_A4        0.000000       0.000000  ...   0.0    0.0    0.000000
# SS2_15_0048_A1       65.766243       0.000000  ...   0.0    0.0    0.000000
# ...                        ...            ...  ...   ...    ...         ...
# SS2_15_0049_P19      37.231979       0.000000  ...   0.0    0.0   21.453518
# SS2_15_0049_P18       0.000000       0.000000  ...   0.0    0.0    0.000000
# SS2_15_0049_P21      62.542484      19.583052  ...   0.0    0.0    0.000000
# SS2_15_0049_P23       0.000000       0.000000  ...   0.0    0.0    0.000000
# SS2_15_0049_P22       0.000000       0.000000  ...   0.0    0.0    0.000000
#
#                  Zfp2       Zfp36    Zfp454  Zfp652os  Zfp81     Zfp944  \
# SS2_15_0048_A3    0.0  201.533078  0.000000       0.0    0.0   0.000000
# SS2_15_0048_A6    0.0  175.071938  0.000000       0.0    0.0   0.000000
# SS2_15_0048_A5    0.0  290.743379  0.000000       0.0    0.0   0.000000
# SS2_15_0048_A4    0.0    0.000000  0.000000       0.0    0.0   0.000000
# SS2_15_0048_A1    0.0  768.997431  0.000000       0.0    0.0   2.413509
# ...               ...         ...       ...       ...    ...        ...
# SS2_15_0049_P19   0.0   19.602162  1.869748       0.0    0.0  34.520490
# SS2_15_0049_P18   0.0   41.641731  0.000000       0.0    0.0   0.000000
# SS2_15_0049_P21   0.0   70.246018  0.000000       0.0    0.0   0.000000
# SS2_15_0049_P23   0.0    0.000000  0.000000       0.0    0.0  55.993812
# SS2_15_0049_P22   0.0  390.824106  0.000000       0.0    0.0   0.000000
#
#                  cluster
# SS2_15_0048_A3         1
# SS2_15_0048_A6         1
# SS2_15_0048_A5         1
# SS2_15_0048_A4         2
# SS2_15_0048_A1         1
# ...                  ...
# SS2_15_0049_P19        3
# SS2_15_0049_P18        2
# SS2_15_0049_P21        1
# SS2_15_0049_P23        2
# SS2_15_0049_P22        1
#
# [716 rows x 558 columns]

# %% [markdown]
# Before going further, try to reflect for a moment how you would try to illuminate any pattern in this data, given what you already know.

# %% [markdown]
# #### Plot the expression matrix

# %%
plt.figure(figsize=(8,8))
plt.imshow(expr.values, cmap='Greens', vmax=4000, vmin=0)
plt.title('Expression matrix')
plt.ylabel('Cells')
plt.xlabel('Genes')
plt.colorbar()
plt.show()

# %% [markdown]
# #### Exercise 2. The data is very sparse (most entries are zero), can you quantify how sparse it is? (i.e. how many of the entries are 0)

# %%
# %load solutions/ex4_2.py
np.count_nonzero(expr.values) / np.prod(expr.shape)

# only 20% of the entries are non-zero.
# Out:
# 0.19622154141887427

# %%
print("\n" + "Dimensions of input file: " + str(expr.shape) + "\n")
print("\n" + "Last column corresponds to cluster assignments: " + "\n")
print(expr.iloc[0:4, (expr.shape[1]-4):expr.shape[1]])
X = expr.values[:,0:(expr.shape[1]-1)]
Y = expr.values[:,expr.shape[1]-1] #cluster
X = np.log(X + 1)
# Out:
# Dimensions of input file: (716, 558)
#
#
# Last column corresponds to cluster assignments:
#
#                 Zfp652os  Zfp81  Zfp944  cluster
# SS2_15_0048_A3       0.0    0.0     0.0        1
# SS2_15_0048_A6       0.0    0.0     0.0        1
# SS2_15_0048_A5       0.0    0.0     0.0        1
# SS2_15_0048_A4       0.0    0.0     0.0        2

# %%
cafs.dtypes.unique()
# Out:
# array([dtype('float64'), dtype('int64')], dtype=object)

# %% [markdown]
# ### Decomposing the signals
# Now that we have gained some basic understanding of the data, we see it is fit for machine learning. You have already seen a few techniques to reduce data dimensionality reduction. We start with PCA

# %%
from sklearn.decomposition import PCA

# %%
#from matplotlib import cm
#dir(cm) # available colors

# %% [markdown]
# #### Exercise 3. Perform PCA on the expression data and visualize the results (with colors to represent the ground truth clusters)

# %%
# %load solutions/ex4_3.py
model = PCA()
pca = model.fit_transform(X)
plt.scatter(pca[:, 0], pca[:, 1], c = Y, cmap = 'rainbow', s = 1)
plt.xlabel("PC1", fontsize = 20); plt.ylabel("PC2", fontsize = 20)
# Out:
# Text(0, 0.5, 'PC2')

# %%
plt.plot(model.explained_variance_ratio_[:10])
plt.xticks(range(10));plt.show()

# %% [markdown]
# PCA is completely unsupervised. Linear discriminant analysis (LDA) is often used for the same purpose as PCA (dimensionality reduction), but is strictly speaking not unsupervised.

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
model = LinearDiscriminantAnalysis(n_components = 2, priors = None, shrinkage = 'auto', 
                                   solver = 'eigen', store_covariance = False, tol = 0.0001)
lda = model.fit_transform(X, Y)
plt.scatter(lda[:, 0], lda[:, 1], c = Y, cmap = 'viridis', s = 1)
plt.xlabel("LDA1", fontsize = 20); plt.ylabel("LDA2", fontsize = 20)
feature_importances = pd.DataFrame({'Gene':np.array(expr.columns)[:-1], 
                                    'Score':abs(model.coef_[0])})
print(feature_importances.sort_values('Score', ascending = False).head(20))
# Out:
#         Gene      Score
# 422    Rn45s  39.249111
# 64       B2m  12.880958
# 212     Fth1   8.174487
# 287    Lars2   7.385672
# 147     Cst3   6.857356
# 315   Malat1   6.290840
# 420     Rgs5   4.681367
# 524    Timp1   4.486659
# 131   Col3a1   3.229705
# 130   Col1a2   3.062976
# 537  Trmt61b   3.020343
# 145    Crip1   2.991499
# 322      Mgp   2.787057
# 368      Mt1   2.673895
# 400    Postn   2.401428
# 534     Tpm1   2.258763
# 248    Hspa5   2.133318
# 241   Higd1b   2.094767
# 220     Ggt1   2.003810
# 122    Cldn4   1.951643

# %% [markdown]
# The way to interpret the data above: we clearly see the data lay in three clusters, suggesting  we have found 3 different separable expression-signatures. However, we also see one cluster is occupied by 2 clusters (the colors are imposed by the fact that we know the "ground truth", but unsupervised methods are generally used for data exploration in which we do not know of these things.

# %% [markdown]
# # Non-linear methods
#
# # t-SNE
#
# t-SNE is a very popular decomposition technique used in molecular biology, especially for visualization purposes. t-SNE does generally not cope well with high dimensionality, so it is common to first transform the data with PCA and then run this through t-SNE. Here we will do both with and without prereducing the dimensionality.

# %%
from sklearn.manifold import TSNE

# %%
model = TSNE(learning_rate = 10, n_components = 2, random_state = 123, perplexity = 30)
tsne = model.fit_transform(X)
# Out:
# F:\miniconda\envs\cbmTest\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(

# %%
plt.scatter(tsne[:, 0], tsne[:, 1], c = Y, cmap = 'rainbow', s = 2, marker='x')
plt.title('tSNE', fontsize = 20)
plt.xlabel("tSNE1", fontsize = 20)
plt.ylabel("tSNE2", fontsize = 20)
# Out:
# Text(0, 0.5, 'tSNE2')

# %% [markdown]
# #### Exercise 4. Reduce the data first with PCA to 30 principal components, then rerun the tSNE on this transformed data.

# %%
# %load solutions/ex4_4.py
X_reduced = PCA(n_components = 30).fit_transform(X)
model = TSNE(learning_rate = 10, n_components = 2, random_state = 123, perplexity = 30)
tsne = model.fit_transform(X_reduced)

plt.scatter(tsne[:, 0], tsne[:, 1], c = Y, cmap = 'rainbow', s = 2, marker='x')
plt.title('tSNE on PCA', fontsize = 20)
plt.xlabel("tSNE1", fontsize = 20)
plt.ylabel("tSNE2", fontsize = 20)
# Out:
# F:\miniconda\envs\cbmTest\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# Text(0, 0.5, 'tSNE2')

# %% [markdown]
# While it can be hard to discern the performance boost of prereduction, we can certainly see that t-SNE performs better than a linear method like PCA. However, non-linearity is no guarantee of success itself. For instance Isomap does not do well with this data.

# %%
from sklearn.manifold import Isomap

# %%
model = Isomap()
isomap = model.fit_transform(X)
plt.scatter(isomap[:, 0], isomap[:, 1], c = Y, cmap = 'viridis', s = 1)
plt.title('ISOMAP')
#plt.colorbar()
plt.xlabel("ISO1")
plt.ylabel("ISO2")
# Out:
# Text(0, 0.5, 'ISO2')

# %% [markdown]
# We should not throw Isomap out the window yet, like most algorithm, there is no one-size-fits-all. Isomap is well suited for tasks without clear clusters, but continuous change is present.

# %% [markdown]
# # UMAP
# A more recent alternative to t-SNE is [UMAP](https://arxiv.org/abs/1802.03426), which also produces high quality visualizations with good separation, and scales better than t-sne with large datasets.

# %%
from umap import UMAP

# %%
print("Performing Uniform Manifold Approximation and Projection (UMAP) ...")
#model = UMAP(n_neighbors = 30, min_dist = 0.3, n_components = 2)
model = UMAP()
umap = model.fit_transform(X) # or X_reduced
# Out:
# Performing Uniform Manifold Approximation and Projection (UMAP) ...

# %%
plt.scatter(umap[:, 0], umap[:, 1], c = Y, cmap = 'viridis', s = 1)
plt.title('UMAP')
#plt.colorbar()
plt.xlabel("UMAP1")
plt.ylabel("UMAP2")
# Out:
# Text(0, 0.5, 'UMAP2')

# %% [markdown]
# #### Conclusion
# In summary, when doing data exploration of gene expression (and other biomedical data), non-linear methods are preferred to linear ones.
